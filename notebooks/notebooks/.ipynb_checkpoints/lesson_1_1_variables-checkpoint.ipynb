# %%
farm_name = "Morzay Farms"
location = "Nigeria"

print(farm_name)
print(location)
# Out:
# Morzay Farms
# Nigeria

# %%
broilers = 50
layers = 20

total_birds = broilers + layers

print(total_birds)
# Out:
# 70

# %%
price_per_bird = 5000
birds_sold = 5

revenue = price_per_bird * birds_sold

print(revenue)
# Out:
# 25000
