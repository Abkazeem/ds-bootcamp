# %%
for i in range(5):
    print("Morzay Farms")
# Out:
# Morzay Farms
# Morzay Farms
# Morzay Farms
# Morzay Farms
# Morzay Farms

# %%
for number in range(1, 6):
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
count = 1

while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1, 4):
    print("Morzay Farms")
# Out:
# Morzay Farms
# Morzay Farms
# Morzay Farms

# %%
count = 1

while count <= 5:
    print(count)
    count = count + 1
# Out:
# 1
# 2
# 3
# 4
# 5
