# %%
age = 45

if age >= 42:
    print("Ready for market")
# Out:
# Ready for market

# %%
birds = 150

if birds > 100:
    print("Large farm")
else:
    print("Small farm")
# Out:
# Large farm

# %%
score = 78

if score >= 70:
    print("Excellent")
elif score >= 50:
    print("Pass")
else:
    print("Fail")
# Out:
# Excellent

# %%
birds = 200

if birds >= 150:
    print("High Stock")
else:
    print("Low Stock")
# Out:
# High Stock

# %%
profit = 50000

if profit > 30000:
    print("Good Business")
else:
    print("Needs Improvement")
# Out:
# Good Business

# %%
age = 35

if age >= 42:
    print("Sell Birds")
else:
    print("Keep Growing")
# Out:
# Keep Growing

# %%
birds = 120

if birds > 100:
    print("Large flock")
# Out:
# Large flock

# %%
temperature = 28

if temperature > 30:
    print("Hot")

else:
    print("Normal")
# Out:
# Normal

# %%
birds = 80

if birds > 100:
    print("Large flock")

elif birds > 50:
    print("Medium flock")

else:
    print("Small flock")
# Out:
# Medium flock

# %%
age = 18

if age >= 18:
    print("Adult")

else:
    print("Minor")
# Out:
# Adult

# %%
revenue = 75000

if revenue > 100000:
    print("High Revenue")

elif revenue > 50000:
    print("Medium Revenue")

else:
    print("Low Revenue")
# Out:
# Medium Revenue

# %%
birds_sold = 120
