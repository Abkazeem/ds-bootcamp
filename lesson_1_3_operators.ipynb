# %%
print(10 + 5)
print(10 - 5)
print(10 * 5)
print(10 / 5)
# Out:
# 15
# 5
# 50
# 2.0

# %%
birds = 100

print(birds > 50)
print(birds == 100)
print(birds < 20)
# Out:
# True
# True
# False

# %%
a = 20
b = 5

a + b
a - b
a * b
a / b
# Out:
# 4.0

# %%
birds = 150
birds > 100
birds < 100
birds == 150
# Out:
# True

# %%
birds < 100
# Out:
# False

# %%
birds == 150
# Out:
# True

# %%
a * b
# Out:
# 100

# %%
birds_sold = 12
price_per_bird = 5000

revenue = birds_sold * price_per_bird
print("Revenue =", revenue)
# Out:
# Revenue = 60000
